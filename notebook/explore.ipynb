# %%
import pandas as pd

# %%
runs = pd.read_csv("data/runs.csv")
runs.head()
# Out:
# /var/folders/h2/wwh3rz9d1nl8_gwmkdhj5r2c0000gn/T/ipykernel_61816/2194193644.py:1: DtypeWarning: Columns (10,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   runs = pd.read_csv("data/runs.csv")
#                  name  ref   country                region  \
# 0                 NaN  NaN    France  Auvergne-Rhône-Alpes
# 1                 NaN  NaN    France  Auvergne-Rhône-Alpes
# 2            Öjberget  NaN   Finland          Ostrobothnia
# 3                 NaN  NaN   Germany               Bavaria
# 4  Ribnica na Pohorju  NaN  Slovenia                   NaN
#
#                     locality     ski_area_names difficulty color oneway  lit  \
# 0                 Les Allues  Les Trois Vallées       easy  blue    yes  NaN
# 1                 Les Allues  Les Trois Vallées       easy  blue    yes  NaN
# 2                      Vaasa           Öjberget        NaN  grey    yes  NaN
# 3  Martinlamitzer Forst Nord                NaN        NaN  grey    yes  NaN
# ...

# %%
resorts = pd.read_csv("data/ski_areas.csv")
resorts.head()
# Out:
#                             name      country                region  \
# 0    Domaine Nordique de Pessade       France  Auvergne-Rhône-Alpes
# 1    Les Charbonnières - Le Lieu  Switzerland                  Vaud
# 2       Cauterets Pont d'Espagne       France                   NaN
# 3  Centre nordique de l'Auberson  Switzerland                  Vaud
# 4                        Méaudre       France  Auvergne-Rhône-Alpes
#
#                      locality     status has_downhill has_nordic  \
# 0            Saulzet-le-Froid  operating           no        yes
# 1                     Le Lieu  operating           no        yes
# 2                   Cauterets  operating          yes        yes
# 3                Sainte-Croix  operating           no        yes
# 4  Autrans-Méaudre en Vercors  operating           no        yes
#
#    downhill_distance_km  nordic_distance_km  vertical_m  ...  \
# 0                   NaN                13.0       266.0  ...
# ...
